# %% [markdown]
# # Training using the Fashion MNIST dataset
# We will train and evaluate an MLP on the Fashion MNIST dataset. It consists of 70.000 grayscale images of 28x28 pixels each, and there are 10 classes.
#
# Hyperparameters:
# 1. Optimizer: Momentum optimization
# 2. Activation function: RELU
# 3. Weight initialization: Default (glorot_uniform)
# 4. Learning rate schedule: Performance scheduling

# %% [markdown]
# ## Setup

# %%
# Common imports
import os
import numpy as np
import pandas as pd
import keras

# Select backend. Default is "tensorflow". Alternatives are "jax" and "torch".
os.environ["KERAS_BACKEND"] = "tensorflow"

# To plot pretty figures
# %matplotlib inline
import matplotlib.pyplot as plt

# %% [markdown]
# ## Load the data

# %%
fashion_mnist = keras.datasets.fashion_mnist
(X_train_full, y_train_full), (X_test, y_test) = fashion_mnist.load_data()

# %%
# Split the full training set into a validation set and a (smaller) training set.
# Normalize the data
X_valid, X_train = X_train_full[:5000] / 255.0, X_train_full[5000:] / 255.0
y_valid, y_train = y_train_full[:5000], y_train_full[5000:]
X_test = X_test / 255.0

# %%
X_train.shape
# Out:
# (55000, 28, 28)

# %% [markdown]
# ## Create a model using the Sequential API

# %%
model = keras.models.Sequential()
# Input layer:
model.add(keras.layers.Flatten(input_shape=[28, 28]))

# Hidden layers:
for layer in range(3):
    model.add(keras.layers.Dense(100, activation="relu"))
        
# Output layer.
model.add(keras.layers.Dense(10, activation="softmax"))
# Out:
# /Users/hk/opt/anaconda3/lib/python3.12/site-packages/keras/src/layers/reshaping/flatten.py:37: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)

# %% [markdown]
# ## Compile the model
# You must at least specify the loss function and the optimizer to use. You can also specify a list of additional metrics to use during training and evaluation.

# %%
# The optimixer is Stochastic Gradient Descent with momentum optimization. The momentum is set to 0.9.
# This value usually works well in practice. We use the default learning rate (0.01).
model.compile(loss="sparse_categorical_crossentropy",
              optimizer=keras.optimizers.SGD(momentum=0.9),
              metrics=["accuracy"])

# %% [markdown]
# ## Train the model

# %%
# EarlyStopping (with rollback to the best model).
early_stopping = keras.callbacks.EarlyStopping(patience=10, restore_best_weights=True)

# Performance scheduling
# (multiply the learning rate by a factor when the error stops dropping for a number of epochs, called patience)
lr_scheduler = keras.callbacks.ReduceLROnPlateau(factor=0.5, patience=4)

# Train the model with early stopping or performance scheduling or both. Training is much faster when
# early stopping is used, but a slightly better accuracy is achieved with performance scheduling alone.
history = model.fit(X_train, y_train, epochs=40,
                    validation_data=(X_valid, y_valid),
                    callbacks=[lr_scheduler, early_stopping])
# Out:
# Epoch 1/40
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 1s 403us/step - accuracy: 0.7164 - loss: 0.7663 - val_accuracy: 0.8552 - val_loss: 0.3998 - learning_rate: 0.0100
# Epoch 2/40
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 1s 367us/step - accuracy: 0.8532 - loss: 0.3978 - val_accuracy: 0.8616 - val_loss: 0.3755 - learning_rate: 0.0100
# Epoch 3/40
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 1s 370us/step - accuracy: 0.8676 - loss: 0.3655 - val_accuracy: 0.8704 - val_loss: 0.3532 - learning_rate: 0.0100
# Epoch 4/40
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 1s 371us/step - accuracy: 0.8763 - loss: 0.3382 - val_accuracy: 0.8722 - val_loss: 0.3543 - learning_rate: 0.0100
# Epoch 5/40
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 1s 403us/step - accuracy: 0.8806 - loss: 0.3195 - val_accuracy: 0.8772 - val_loss: 0.3342 - learning_rate: 0.0100
# Epoch 6/40
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 1s 373us/step - accuracy: 0.8880 - loss: 0.2975 - val_accuracy: 0.8780 - val_loss: 0.3331 - learning_rate: 0.0100
# Epoch 7/40
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 1s 376us/step - accuracy: 0.8957 - loss: 0.2857 - val_accuracy: 0.8898 - val_loss: 0.3044 - learning_rate: 0.0100
# Epoch 8/40
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 1s 377us/step - accuracy: 0.8962 - loss: 0.2773 - val_accuracy: 0.8776 - val_loss: 0.3359 - learning_rate: 0.0100
# Epoch 9/40
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 1s 378us/step - accuracy: 0.9011 - loss: 0.2659 - val_accuracy: 0.8808 - val_loss: 0.3085 - learning_rate: 0.0100
# Epoch 10/40
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 1s 374us/step - accuracy: 0.9000 - loss: 0.2628 - val_accuracy: 0.8904 - val_loss: 0.2994 - learning_rate: 0.0100
# Epoch 11/40
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 1s 385us/step - accuracy: 0.9060 - loss: 0.2519 - val_accuracy: 0.8850 - val_loss: 0.3185 - learning_rate: 0.0100
# Epoch 12/40
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 1s 378us/step - accuracy: 0.9067 - loss: 0.2463 - val_accuracy: 0.8890 - val_loss: 0.3182 - learning_rate: 0.0100
# Epoch 13/40
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 1s 382us/step - accuracy: 0.9068 - loss: 0.2431 - val_accuracy: 0.8908 - val_loss: 0.3109 - learning_rate: 0.0100
# Epoch 14/40
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 1s 381us/step - accuracy: 0.9131 - loss: 0.2306 - val_accuracy: 0.8880 - val_loss: 0.3053 - learning_rate: 0.0100
# Epoch 15/40
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 1s 389us/step - accuracy: 0.9237 - loss: 0.2005 - val_accuracy: 0.8950 - val_loss: 0.2887 - learning_rate: 0.0050
# Epoch 16/40
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 1s 383us/step - accuracy: 0.9268 - loss: 0.1906 - val_accuracy: 0.8920 - val_loss: 0.2911 - learning_rate: 0.0050
# Epoch 17/40
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 1s 379us/step - accuracy: 0.9280 - loss: 0.1860 - val_accuracy: 0.8954 - val_loss: 0.2902 - learning_rate: 0.0050
# Epoch 18/40
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 1s 376us/step - accuracy: 0.9321 - loss: 0.1785 - val_accuracy: 0.8958 - val_loss: 0.3084 - learning_rate: 0.0050
# Epoch 19/40
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 1s 408us/step - accuracy: 0.9331 - loss: 0.1761 - val_accuracy: 0.8964 - val_loss: 0.2910 - learning_rate: 0.0050
# Epoch 20/40
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 1s 377us/step - accuracy: 0.9375 - loss: 0.1605 - val_accuracy: 0.8990 - val_loss: 0.2876 - learning_rate: 0.0025
# Epoch 21/40
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 1s 379us/step - accuracy: 0.9409 - loss: 0.1542 - val_accuracy: 0.8992 - val_loss: 0.2934 - learning_rate: 0.0025
# Epoch 22/40
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 1s 379us/step - accuracy: 0.9420 - loss: 0.1531 - val_accuracy: 0.8982 - val_loss: 0.2978 - learning_rate: 0.0025
# Epoch 23/40
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 1s 387us/step - accuracy: 0.9423 - loss: 0.1467 - val_accuracy: 0.8984 - val_loss: 0.3072 - learning_rate: 0.0025
# Epoch 24/40
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 1s 389us/step - accuracy: 0.9453 - loss: 0.1459 - val_accuracy: 0.8988 - val_loss: 0.2988 - learning_rate: 0.0025
# Epoch 25/40
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 1s 388us/step - accuracy: 0.9494 - loss: 0.1362 - val_accuracy: 0.8984 - val_loss: 0.2991 - learning_rate: 0.0012
# Epoch 26/40
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 1s 391us/step - accuracy: 0.9501 - loss: 0.1308 - val_accuracy: 0.9006 - val_loss: 0.3018 - learning_rate: 0.0012
# Epoch 27/40
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 1s 380us/step - accuracy: 0.9505 - loss: 0.1296 - val_accuracy: 0.8996 - val_loss: 0.3088 - learning_rate: 0.0012
# Epoch 28/40
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 1s 385us/step - accuracy: 0.9536 - loss: 0.1251 - val_accuracy: 0.8980 - val_loss: 0.3042 - learning_rate: 0.0012
# Epoch 29/40
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 1s 379us/step - accuracy: 0.9543 - loss: 0.1206 - val_accuracy: 0.8994 - val_loss: 0.3066 - learning_rate: 6.2500e-04
# Epoch 30/40
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 1s 387us/step - accuracy: 0.9533 - loss: 0.1213 - val_accuracy: 0.8988 - val_loss: 0.3065 - learning_rate: 6.2500e-04

# %%
# Show the learning curves.
# (The training curves should be shifted half an epoch to the left to be completely comparable with
# the validation curves).

pd.DataFrame(history.history).plot(figsize=(8, 5))
plt.grid(True)
plt.gca().set_ylim(0, 1)
plt.show()

# %% [markdown]
# ## Evaluate the model.

# %%
model.evaluate(X_test, y_test)
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 217us/step - accuracy: 0.8936 - loss: 0.3359
# [0.3274877071380615, 0.8930000066757202]
