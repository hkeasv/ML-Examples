# %% [markdown]
# # Training using the Fashion MNIST dataset
# We will train and evaluate an MLP on the Fashion MNIST dataset. It consists of 70.000 grayscale images of 28x28 pixels each, and there are 10 classes.
#
# Hyperparameters:
# 1. Optimizer: Momentum optimization
# 2. Activation function: RELU
# 3. Weight initialization: Default (glorot_uniform)

# %% [markdown]
# ## Setup

# %%
# Common imports
import os
import numpy as np
import pandas as pd
import keras

# Select backend. Default is "tensorflow". Alternatives are "jax" and "torch".
os.environ["KERAS_BACKEND"] = "tensorflow"

# To plot pretty figures
# %matplotlib inline
import matplotlib.pyplot as plt

# %% [markdown]
# ## Load the data

# %%
fashion_mnist = keras.datasets.fashion_mnist
(X_train_full, y_train_full), (X_test, y_test) = fashion_mnist.load_data()

# %%
# Split the full training set into a validation set and a (smaller) training set.
# Normalize the data
X_valid, X_train = X_train_full[:5000] / 255.0, X_train_full[5000:] / 255.0
y_valid, y_train = y_train_full[:5000], y_train_full[5000:]
X_test = X_test / 255.0

# %%
X_train.shape
# Out:
# (55000, 28, 28)

# %% [markdown]
# ## Create a model using the Sequential API

# %%
model = keras.models.Sequential()
# Input layer:
model.add(keras.layers.Flatten(input_shape=[28, 28]))

# Hidden layers:
for layer in range(3):
    model.add(keras.layers.Dense(100, activation="relu"))
        
# Output layer.
model.add(keras.layers.Dense(10, activation="softmax"))
# Out:
# /Users/hk/opt/anaconda3/lib/python3.12/site-packages/keras/src/layers/reshaping/flatten.py:37: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)

# %% [markdown]
# ## Compile the model
# You must at least specify the loss function and the optimizer to use. You can also specify a list of additional metrics to use during training and evaluation.

# %%
# The optimixer is Stochastic Gradient Descent with momentum optimization. The momentum is set to 0.9.
# This value usually works well in practice. We use the default learning rate (0.01).
model.compile(loss="sparse_categorical_crossentropy",
              optimizer=keras.optimizers.SGD(momentum=0.9),
              metrics=["accuracy"])

# %% [markdown]
# ## Train the model

# %%
# EarlyStopping (with rollback to the best model).
early_stopping = keras.callbacks.EarlyStopping(patience=10, restore_best_weights=True)

# Train the model with early stopping.
history = model.fit(X_train, y_train, epochs=40,
                    validation_data=(X_valid, y_valid),
                    callbacks=[early_stopping])
# Out:
# Epoch 1/40
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 1s 402us/step - accuracy: 0.7300 - loss: 0.7490 - val_accuracy: 0.8556 - val_loss: 0.4000
# Epoch 2/40
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 1s 370us/step - accuracy: 0.8496 - loss: 0.4126 - val_accuracy: 0.8658 - val_loss: 0.3606
# Epoch 3/40
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 1s 372us/step - accuracy: 0.8627 - loss: 0.3720 - val_accuracy: 0.8720 - val_loss: 0.3443
# Epoch 4/40
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 1s 370us/step - accuracy: 0.8774 - loss: 0.3291 - val_accuracy: 0.8760 - val_loss: 0.3380
# Epoch 5/40
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 1s 374us/step - accuracy: 0.8811 - loss: 0.3136 - val_accuracy: 0.8688 - val_loss: 0.3537
# Epoch 6/40
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 1s 380us/step - accuracy: 0.8878 - loss: 0.2956 - val_accuracy: 0.8806 - val_loss: 0.3224
# Epoch 7/40
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 1s 383us/step - accuracy: 0.8910 - loss: 0.2860 - val_accuracy: 0.8834 - val_loss: 0.3170
# Epoch 8/40
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 1s 388us/step - accuracy: 0.8958 - loss: 0.2757 - val_accuracy: 0.8782 - val_loss: 0.3349
# Epoch 9/40
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 1s 382us/step - accuracy: 0.9001 - loss: 0.2628 - val_accuracy: 0.8804 - val_loss: 0.3204
# Epoch 10/40
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 1s 410us/step - accuracy: 0.9024 - loss: 0.2602 - val_accuracy: 0.8878 - val_loss: 0.3110
# Epoch 11/40
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 1s 395us/step - accuracy: 0.9078 - loss: 0.2418 - val_accuracy: 0.8876 - val_loss: 0.3039
# Epoch 12/40
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 1s 392us/step - accuracy: 0.9100 - loss: 0.2407 - val_accuracy: 0.8786 - val_loss: 0.3405
# Epoch 13/40
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 1s 386us/step - accuracy: 0.9105 - loss: 0.2382 - val_accuracy: 0.8918 - val_loss: 0.3097
# Epoch 14/40
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 1s 374us/step - accuracy: 0.9139 - loss: 0.2293 - val_accuracy: 0.8912 - val_loss: 0.2983
# Epoch 15/40
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 1s 378us/step - accuracy: 0.9156 - loss: 0.2221 - val_accuracy: 0.8870 - val_loss: 0.3240
# Epoch 16/40
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 1s 376us/step - accuracy: 0.9187 - loss: 0.2152 - val_accuracy: 0.8898 - val_loss: 0.3020
# Epoch 17/40
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 1s 373us/step - accuracy: 0.9213 - loss: 0.2076 - val_accuracy: 0.8934 - val_loss: 0.3250
# Epoch 18/40
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 1s 382us/step - accuracy: 0.9236 - loss: 0.1991 - val_accuracy: 0.8832 - val_loss: 0.3584
# Epoch 19/40
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 1s 387us/step - accuracy: 0.9215 - loss: 0.2066 - val_accuracy: 0.8952 - val_loss: 0.3064
# Epoch 20/40
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 1s 386us/step - accuracy: 0.9238 - loss: 0.1947 - val_accuracy: 0.8906 - val_loss: 0.3230
# Epoch 21/40
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 1s 388us/step - accuracy: 0.9280 - loss: 0.1904 - val_accuracy: 0.8942 - val_loss: 0.3103
# Epoch 22/40
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 1s 388us/step - accuracy: 0.9275 - loss: 0.1863 - val_accuracy: 0.8958 - val_loss: 0.3216
# Epoch 23/40
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 1s 386us/step - accuracy: 0.9325 - loss: 0.1771 - val_accuracy: 0.8950 - val_loss: 0.3210
# Epoch 24/40
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 1s 380us/step - accuracy: 0.9341 - loss: 0.1766 - val_accuracy: 0.8870 - val_loss: 0.3580

# %%
# Show the learning curves.
# (The training curves should be shifted half an epoch to the left to be completely comparable with
# the validation curves).

pd.DataFrame(history.history).plot(figsize=(8, 5))
plt.grid(True)
plt.gca().set_ylim(0, 1)
plt.show()

# %% [markdown]
# ## Evaluate the model.

# %%
model.evaluate(X_test, y_test)
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 216us/step - accuracy: 0.8786 - loss: 0.3402
# [0.3308964967727661, 0.883400022983551]
