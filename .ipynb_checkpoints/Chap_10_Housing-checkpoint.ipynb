# %% [markdown]
# # MLP Regressor trained with the California housing dataset

# %% [markdown]
# ## Setup

# %%
# Common imports
import os
import numpy as np
import pandas as pd
import keras

# Select backend. Default is "tensorflow". Alternatives are "jax" and "torch".
os.environ["KERAS_BACKEND"] = "tensorflow"

# To plot pretty figures
# %matplotlib inline
import matplotlib.pyplot as plt

# %% [markdown]
# ## Load and split the dataset

# %%
from sklearn.datasets import fetch_california_housing
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MinMaxScaler

housing = fetch_california_housing()

X_train_full, X_test, y_train_full, y_test = train_test_split(housing.data, housing.target, random_state=42)
X_train, X_valid, y_train, y_valid = train_test_split(X_train_full, y_train_full, random_state=42)

# We could scale the features using SciKitLearn's StandardScaler or MinMaxScaler,
# but in this example we will use the Keras Normalization Layer instead.
#scaler = StandardScaler()
#X_train = scaler.fit_transform(X_train)
#X_valid = scaler.transform(X_valid)
#X_test = scaler.transform(X_test)

# %%
# Display the feature names.
# Note that this dataset is not exactly the same as the "housing" dataset used in chapter 2.
# As a result, we cannot completely compare the RMSE of this model with the RMSEs of the
# other models that we trained and tested using the dataset from chapter 2.
housing.feature_names
# Out:
# ['MedInc',
#  'HouseAge',
#  'AveRooms',
#  'AveBedrms',
#  'Population',
#  'AveOccup',
#  'Latitude',
#  'Longitude']

# %%
# Display the number of rows and columns in the features array.

# %%
housing.data.shape
# Out:
# (20640, 8)

# %%
# Computing the mean median_house_value.
# We can see that the target value have been scaled down by a factor of 100000
# compared to the unprepared Housing dataset that we have used earlier.

# %%
housing.target.mean()
# Out:
# 2.068558169089147

# %% [markdown]
# ## Build, compile, train and evaluate a model

# %%
# Build a model.
# We don't need to specify an input layer, since we don't need to convert the input array.
# For regression problems, we don't use an activation function in the output layer.

# Keras Normalization Layer. See:
#   https://www.tensorflow.org/api_docs/python/tf/keras/layers/Normalization
norm_layer = keras.layers.Normalization()

model = keras.models.Sequential([
    norm_layer,
    # hidden layers
    keras.layers.Dense(100, activation="relu"),
    keras.layers.Dense(100, activation="relu"),
    keras.layers.Dense(100, activation="relu"),
    keras.layers.Dense(100, activation="relu"),
    # output layer
    keras.layers.Dense(1)
])

# Compile the model.
# For regression problems, we use the "mean_squared_error" as loss function.
model.compile(loss="mse", optimizer=keras.optimizers.SGD(learning_rate=0.001), metrics=["RootMeanSquaredError"])

# Normalize inputs.
norm_layer.adapt(X_train)

# %%
# Train the model.
history = model.fit(X_train, y_train, epochs=150, validation_data=(X_valid, y_valid))
# Out:
# Epoch 1/150
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 418us/step - RootMeanSquaredError: 1.6780 - loss: 2.8847 - val_RootMeanSquaredError: 1.7838 - val_loss: 3.1818
# Epoch 2/150
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 297us/step - RootMeanSquaredError: 0.8926 - loss: 0.7977 - val_RootMeanSquaredError: 0.8566 - val_loss: 0.7338
# Epoch 3/150
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 294us/step - RootMeanSquaredError: 0.7892 - loss: 0.6230 - val_RootMeanSquaredError: 0.7695 - val_loss: 0.5921
# Epoch 4/150
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 308us/step - RootMeanSquaredError: 0.7491 - loss: 0.5617 - val_RootMeanSquaredError: 0.7284 - val_loss: 0.5305
# Epoch 5/150
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 300us/step - RootMeanSquaredError: 0.7351 - loss: 0.5409 - val_RootMeanSquaredError: 0.6995 - val_loss: 0.4892
# Epoch 6/150
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 297us/step - RootMeanSquaredError: 0.6963 - loss: 0.4850 - val_RootMeanSquaredError: 0.6736 - val_loss: 0.4538
# Epoch 7/150
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 295us/step - RootMeanSquaredError: 0.6807 - loss: 0.4636 - val_RootMeanSquaredError: 0.6546 - val_loss: 0.4285
# Epoch 8/150
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 294us/step - RootMeanSquaredError: 0.6625 - loss: 0.4389 - val_RootMeanSquaredError: 0.6442 - val_loss: 0.4149
# Epoch 9/150
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 295us/step - RootMeanSquaredError: 0.6518 - loss: 0.4252 - val_RootMeanSquaredError: 0.6347 - val_loss: 0.4028
# Epoch 10/150
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 289us/step - RootMeanSquaredError: 0.6301 - loss: 0.3971 - val_RootMeanSquaredError: 0.6321 - val_loss: 0.3996
# Epoch 11/150
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 306us/step - RootMeanSquaredError: 0.6156 - loss: 0.3791 - val_RootMeanSquaredError: 0.6311 - val_loss: 0.3983
# Epoch 12/150
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 298us/step - RootMeanSquaredError: 0.6191 - loss: 0.3835 - val_RootMeanSquaredError: 0.6310 - val_loss: 0.3982
# Epoch 13/150
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 300us/step - RootMeanSquaredError: 0.6225 - loss: 0.3876 - val_RootMeanSquaredError: 0.6395 - val_loss: 0.4090
# Epoch 14/150
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 312us/step - RootMeanSquaredError: 0.6082 - loss: 0.3702 - val_RootMeanSquaredError: 0.6364 - val_loss: 0.4050
# Epoch 15/150
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 302us/step - RootMeanSquaredError: 0.6124 - loss: 0.3755 - val_RootMeanSquaredError: 0.6332 - val_loss: 0.4009
# Epoch 16/150
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 292us/step - RootMeanSquaredError: 0.5951 - loss: 0.3546 - val_RootMeanSquaredError: 0.6404 - val_loss: 0.4101
# Epoch 17/150
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 290us/step - RootMeanSquaredError: 0.6018 - loss: 0.3622 - val_RootMeanSquaredError: 0.6402 - val_loss: 0.4099
# Epoch 18/150
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 290us/step - RootMeanSquaredError: 0.5828 - loss: 0.3402 - val_RootMeanSquaredError: 0.6381 - val_loss: 0.4071
# Epoch 19/150
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 292us/step - RootMeanSquaredError: 0.6017 - loss: 0.3623 - val_RootMeanSquaredError: 0.6450 - val_loss: 0.4160
# Epoch 20/150
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 288us/step - RootMeanSquaredError: 0.5873 - loss: 0.3451 - val_RootMeanSquaredError: 0.6341 - val_loss: 0.4020
# Epoch 21/150
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 407us/step - RootMeanSquaredError: 0.5889 - loss: 0.3470 - val_RootMeanSquaredError: 0.6410 - val_loss: 0.4109
# Epoch 22/150
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 314us/step - RootMeanSquaredError: 0.5793 - loss: 0.3358 - val_RootMeanSquaredError: 0.6296 - val_loss: 0.3964
# Epoch 23/150
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 296us/step - RootMeanSquaredError: 0.5986 - loss: 0.3584 - val_RootMeanSquaredError: 0.6237 - val_loss: 0.3890
# Epoch 24/150
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 290us/step - RootMeanSquaredError: 0.5885 - loss: 0.3467 - val_RootMeanSquaredError: 0.6346 - val_loss: 0.4027
# Epoch 25/150
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 299us/step - RootMeanSquaredError: 0.5841 - loss: 0.3413 - val_RootMeanSquaredError: 0.6316 - val_loss: 0.3989
# Epoch 26/150
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 289us/step - RootMeanSquaredError: 0.5821 - loss: 0.3390 - val_RootMeanSquaredError: 0.6337 - val_loss: 0.4016
# Epoch 27/150
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 293us/step - RootMeanSquaredError: 0.5824 - loss: 0.3396 - val_RootMeanSquaredError: 0.6441 - val_loss: 0.4149
# Epoch 28/150
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 310us/step - RootMeanSquaredError: 0.5819 - loss: 0.3388 - val_RootMeanSquaredError: 0.6268 - val_loss: 0.3929
# Epoch 29/150
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 331us/step - RootMeanSquaredError: 0.5798 - loss: 0.3363 - val_RootMeanSquaredError: 0.6358 - val_loss: 0.4043
# Epoch 30/150
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 307us/step - RootMeanSquaredError: 0.5817 - loss: 0.3385 - val_RootMeanSquaredError: 0.6130 - val_loss: 0.3757
# Epoch 31/150
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 309us/step - RootMeanSquaredError: 0.5872 - loss: 0.3449 - val_RootMeanSquaredError: 0.6223 - val_loss: 0.3873
# Epoch 32/150
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 308us/step - RootMeanSquaredError: 0.5748 - loss: 0.3305 - val_RootMeanSquaredError: 0.6154 - val_loss: 0.3787
# Epoch 33/150
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 295us/step - RootMeanSquaredError: 0.5787 - loss: 0.3350 - val_RootMeanSquaredError: 0.6127 - val_loss: 0.3754
# Epoch 34/150
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 287us/step - RootMeanSquaredError: 0.5761 - loss: 0.3320 - val_RootMeanSquaredError: 0.6175 - val_loss: 0.3813
# Epoch 35/150
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 302us/step - RootMeanSquaredError: 0.5749 - loss: 0.3306 - val_RootMeanSquaredError: 0.6155 - val_loss: 0.3788
# Epoch 36/150
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 311us/step - RootMeanSquaredError: 0.5753 - loss: 0.3311 - val_RootMeanSquaredError: 0.6146 - val_loss: 0.3777
# Epoch 37/150
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 306us/step - RootMeanSquaredError: 0.5750 - loss: 0.3308 - val_RootMeanSquaredError: 0.6000 - val_loss: 0.3599
# Epoch 38/150
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 310us/step - RootMeanSquaredError: 0.5766 - loss: 0.3327 - val_RootMeanSquaredError: 0.5949 - val_loss: 0.3540
# Epoch 39/150
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 298us/step - RootMeanSquaredError: 0.5624 - loss: 0.3167 - val_RootMeanSquaredError: 0.6096 - val_loss: 0.3716
# Epoch 40/150
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 297us/step - RootMeanSquaredError: 0.5836 - loss: 0.3412 - val_RootMeanSquaredError: 0.6052 - val_loss: 0.3663
# Epoch 41/150
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 297us/step - RootMeanSquaredError: 0.5774 - loss: 0.3339 - val_RootMeanSquaredError: 0.5949 - val_loss: 0.3539
# Epoch 42/150
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 290us/step - RootMeanSquaredError: 0.5704 - loss: 0.3255 - val_RootMeanSquaredError: 0.5974 - val_loss: 0.3568
# Epoch 43/150
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 297us/step - RootMeanSquaredError: 0.5684 - loss: 0.3232 - val_RootMeanSquaredError: 0.6013 - val_loss: 0.3616
# Epoch 44/150
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 295us/step - RootMeanSquaredError: 0.5550 - loss: 0.3083 - val_RootMeanSquaredError: 0.6080 - val_loss: 0.3697
# Epoch 45/150
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 288us/step - RootMeanSquaredError: 0.5704 - loss: 0.3254 - val_RootMeanSquaredError: 0.5969 - val_loss: 0.3563
# Epoch 46/150
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 291us/step - RootMeanSquaredError: 0.5538 - loss: 0.3070 - val_RootMeanSquaredError: 0.6124 - val_loss: 0.3751
# Epoch 47/150
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 286us/step - RootMeanSquaredError: 0.5672 - loss: 0.3218 - val_RootMeanSquaredError: 0.5826 - val_loss: 0.3394
# Epoch 48/150
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 289us/step - RootMeanSquaredError: 0.5584 - loss: 0.3119 - val_RootMeanSquaredError: 0.6019 - val_loss: 0.3623
# Epoch 49/150
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 291us/step - RootMeanSquaredError: 0.5677 - loss: 0.3223 - val_RootMeanSquaredError: 0.6127 - val_loss: 0.3754
# Epoch 50/150
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 404us/step - RootMeanSquaredError: 0.5561 - loss: 0.3093 - val_RootMeanSquaredError: 0.6034 - val_loss: 0.3641
# Epoch 51/150
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 317us/step - RootMeanSquaredError: 0.5730 - loss: 0.3286 - val_RootMeanSquaredError: 0.5783 - val_loss: 0.3345
# Epoch 52/150
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 306us/step - RootMeanSquaredError: 0.5658 - loss: 0.3210 - val_RootMeanSquaredError: 0.5888 - val_loss: 0.3467
# Epoch 53/150
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 302us/step - RootMeanSquaredError: 0.5634 - loss: 0.3175 - val_RootMeanSquaredError: 0.5963 - val_loss: 0.3556
# Epoch 54/150
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 308us/step - RootMeanSquaredError: 0.5665 - loss: 0.3211 - val_RootMeanSquaredError: 0.5802 - val_loss: 0.3366
# Epoch 55/150
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 300us/step - RootMeanSquaredError: 0.5510 - loss: 0.3038 - val_RootMeanSquaredError: 0.5762 - val_loss: 0.3320
# Epoch 56/150
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 299us/step - RootMeanSquaredError: 0.5597 - loss: 0.3137 - val_RootMeanSquaredError: 0.5984 - val_loss: 0.3580
# Epoch 57/150
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 299us/step - RootMeanSquaredError: 0.5555 - loss: 0.3087 - val_RootMeanSquaredError: 0.5927 - val_loss: 0.3512
# Epoch 58/150
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 310us/step - RootMeanSquaredError: 0.5421 - loss: 0.2944 - val_RootMeanSquaredError: 0.5749 - val_loss: 0.3305
# Epoch 59/150
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 319us/step - RootMeanSquaredError: 0.5467 - loss: 0.2990 - val_RootMeanSquaredError: 0.5833 - val_loss: 0.3402
# Epoch 60/150
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 301us/step - RootMeanSquaredError: 0.5464 - loss: 0.2986 - val_RootMeanSquaredError: 0.5678 - val_loss: 0.3224
# Epoch 61/150
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 314us/step - RootMeanSquaredError: 0.5580 - loss: 0.3115 - val_RootMeanSquaredError: 0.5963 - val_loss: 0.3556
# Epoch 62/150
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 309us/step - RootMeanSquaredError: 0.5533 - loss: 0.3064 - val_RootMeanSquaredError: 0.5743 - val_loss: 0.3299
# Epoch 63/150
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 300us/step - RootMeanSquaredError: 0.5587 - loss: 0.3126 - val_RootMeanSquaredError: 0.5937 - val_loss: 0.3525
# Epoch 64/150
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 305us/step - RootMeanSquaredError: 0.5494 - loss: 0.3020 - val_RootMeanSquaredError: 0.5762 - val_loss: 0.3320
# Epoch 65/150
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 295us/step - RootMeanSquaredError: 0.5645 - loss: 0.3191 - val_RootMeanSquaredError: 0.5897 - val_loss: 0.3478
# Epoch 66/150
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 302us/step - RootMeanSquaredError: 0.5481 - loss: 0.3007 - val_RootMeanSquaredError: 0.5635 - val_loss: 0.3176
# Epoch 67/150
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 297us/step - RootMeanSquaredError: 0.5601 - loss: 0.3139 - val_RootMeanSquaredError: 0.5797 - val_loss: 0.3360
# Epoch 68/150
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 295us/step - RootMeanSquaredError: 0.5471 - loss: 0.2994 - val_RootMeanSquaredError: 0.5809 - val_loss: 0.3374
# Epoch 69/150
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 292us/step - RootMeanSquaredError: 0.5476 - loss: 0.3000 - val_RootMeanSquaredError: 0.5657 - val_loss: 0.3200
# Epoch 70/150
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 292us/step - RootMeanSquaredError: 0.5533 - loss: 0.3063 - val_RootMeanSquaredError: 0.5663 - val_loss: 0.3207
# Epoch 71/150
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 297us/step - RootMeanSquaredError: 0.5415 - loss: 0.2934 - val_RootMeanSquaredError: 0.5838 - val_loss: 0.3409
# Epoch 72/150
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 408us/step - RootMeanSquaredError: 0.5560 - loss: 0.3094 - val_RootMeanSquaredError: 0.5570 - val_loss: 0.3102
# Epoch 73/150
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 307us/step - RootMeanSquaredError: 0.5510 - loss: 0.3037 - val_RootMeanSquaredError: 0.5667 - val_loss: 0.3212
# Epoch 74/150
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 312us/step - RootMeanSquaredError: 0.5384 - loss: 0.2901 - val_RootMeanSquaredError: 0.5855 - val_loss: 0.3428
# Epoch 75/150
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 308us/step - RootMeanSquaredError: 0.5494 - loss: 0.3020 - val_RootMeanSquaredError: 0.5507 - val_loss: 0.3033
# Epoch 76/150
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 317us/step - RootMeanSquaredError: 0.5394 - loss: 0.2911 - val_RootMeanSquaredError: 0.5600 - val_loss: 0.3136
# Epoch 77/150
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 311us/step - RootMeanSquaredError: 0.5456 - loss: 0.2981 - val_RootMeanSquaredError: 0.5747 - val_loss: 0.3302
# Epoch 78/150
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 318us/step - RootMeanSquaredError: 0.5432 - loss: 0.2952 - val_RootMeanSquaredError: 0.5463 - val_loss: 0.2984
# Epoch 79/150
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 305us/step - RootMeanSquaredError: 0.5491 - loss: 0.3017 - val_RootMeanSquaredError: 0.5610 - val_loss: 0.3148
# Epoch 80/150
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 302us/step - RootMeanSquaredError: 0.5321 - loss: 0.2834 - val_RootMeanSquaredError: 0.5778 - val_loss: 0.3339
# Epoch 81/150
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 303us/step - RootMeanSquaredError: 0.5330 - loss: 0.2845 - val_RootMeanSquaredError: 0.5551 - val_loss: 0.3081
# Epoch 82/150
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 305us/step - RootMeanSquaredError: 0.5367 - loss: 0.2882 - val_RootMeanSquaredError: 0.5553 - val_loss: 0.3084
# Epoch 83/150
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 322us/step - RootMeanSquaredError: 0.5373 - loss: 0.2890 - val_RootMeanSquaredError: 0.5690 - val_loss: 0.3238
# Epoch 84/150
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 314us/step - RootMeanSquaredError: 0.5479 - loss: 0.3003 - val_RootMeanSquaredError: 0.5427 - val_loss: 0.2945
# Epoch 85/150
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 314us/step - RootMeanSquaredError: 0.5406 - loss: 0.2924 - val_RootMeanSquaredError: 0.5701 - val_loss: 0.3250
# Epoch 86/150
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 309us/step - RootMeanSquaredError: 0.5484 - loss: 0.3009 - val_RootMeanSquaredError: 0.5788 - val_loss: 0.3350
# Epoch 87/150
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 301us/step - RootMeanSquaredError: 0.5319 - loss: 0.2831 - val_RootMeanSquaredError: 0.5711 - val_loss: 0.3261
# Epoch 88/150
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 303us/step - RootMeanSquaredError: 0.5326 - loss: 0.2838 - val_RootMeanSquaredError: 0.5395 - val_loss: 0.2911
# Epoch 89/150
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 298us/step - RootMeanSquaredError: 0.5266 - loss: 0.2775 - val_RootMeanSquaredError: 0.5727 - val_loss: 0.3279
# Epoch 90/150
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 319us/step - RootMeanSquaredError: 0.5384 - loss: 0.2899 - val_RootMeanSquaredError: 0.5555 - val_loss: 0.3086
# Epoch 91/150
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 309us/step - RootMeanSquaredError: 0.5275 - loss: 0.2783 - val_RootMeanSquaredError: 0.5691 - val_loss: 0.3239
# Epoch 92/150
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 405us/step - RootMeanSquaredError: 0.5443 - loss: 0.2964 - val_RootMeanSquaredError: 0.5781 - val_loss: 0.3342
# Epoch 93/150
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 310us/step - RootMeanSquaredError: 0.5423 - loss: 0.2942 - val_RootMeanSquaredError: 0.5609 - val_loss: 0.3146
# Epoch 94/150
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 315us/step - RootMeanSquaredError: 0.5306 - loss: 0.2816 - val_RootMeanSquaredError: 0.5679 - val_loss: 0.3226
# Epoch 95/150
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 307us/step - RootMeanSquaredError: 0.5426 - loss: 0.2945 - val_RootMeanSquaredError: 0.5600 - val_loss: 0.3136
# Epoch 96/150
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 312us/step - RootMeanSquaredError: 0.5259 - loss: 0.2767 - val_RootMeanSquaredError: 0.5488 - val_loss: 0.3012
# Epoch 97/150
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 317us/step - RootMeanSquaredError: 0.5290 - loss: 0.2800 - val_RootMeanSquaredError: 0.5522 - val_loss: 0.3050
# Epoch 98/150
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 300us/step - RootMeanSquaredError: 0.5237 - loss: 0.2744 - val_RootMeanSquaredError: 0.5495 - val_loss: 0.3020
# Epoch 99/150
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 299us/step - RootMeanSquaredError: 0.5384 - loss: 0.2900 - val_RootMeanSquaredError: 0.5419 - val_loss: 0.2937
# Epoch 100/150
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 303us/step - RootMeanSquaredError: 0.5305 - loss: 0.2814 - val_RootMeanSquaredError: 0.5509 - val_loss: 0.3035
# Epoch 101/150
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 307us/step - RootMeanSquaredError: 0.5285 - loss: 0.2794 - val_RootMeanSquaredError: 0.5520 - val_loss: 0.3047
# Epoch 102/150
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 312us/step - RootMeanSquaredError: 0.5349 - loss: 0.2863 - val_RootMeanSquaredError: 0.5417 - val_loss: 0.2934
# Epoch 103/150
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 311us/step - RootMeanSquaredError: 0.5240 - loss: 0.2748 - val_RootMeanSquaredError: 0.5424 - val_loss: 0.2942
# Epoch 104/150
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 304us/step - RootMeanSquaredError: 0.5193 - loss: 0.2699 - val_RootMeanSquaredError: 0.5605 - val_loss: 0.3142
# Epoch 105/150
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 320us/step - RootMeanSquaredError: 0.5256 - loss: 0.2765 - val_RootMeanSquaredError: 0.5535 - val_loss: 0.3064
# Epoch 106/150
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 320us/step - RootMeanSquaredError: 0.5279 - loss: 0.2787 - val_RootMeanSquaredError: 0.5722 - val_loss: 0.3274
# Epoch 107/150
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 311us/step - RootMeanSquaredError: 0.5265 - loss: 0.2773 - val_RootMeanSquaredError: 0.5640 - val_loss: 0.3181
# Epoch 108/150
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 313us/step - RootMeanSquaredError: 0.5391 - loss: 0.2911 - val_RootMeanSquaredError: 0.5487 - val_loss: 0.3011
# Epoch 109/150
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 405us/step - RootMeanSquaredError: 0.5298 - loss: 0.2808 - val_RootMeanSquaredError: 0.5412 - val_loss: 0.2929
# Epoch 110/150
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 306us/step - RootMeanSquaredError: 0.5256 - loss: 0.2764 - val_RootMeanSquaredError: 0.5466 - val_loss: 0.2988
# Epoch 111/150
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 307us/step - RootMeanSquaredError: 0.5197 - loss: 0.2703 - val_RootMeanSquaredError: 0.5340 - val_loss: 0.2852
# Epoch 112/150
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 300us/step - RootMeanSquaredError: 0.5203 - loss: 0.2709 - val_RootMeanSquaredError: 0.5781 - val_loss: 0.3342
# Epoch 113/150
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 308us/step - RootMeanSquaredError: 0.5228 - loss: 0.2734 - val_RootMeanSquaredError: 0.5460 - val_loss: 0.2982
# Epoch 114/150
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 304us/step - RootMeanSquaredError: 0.5273 - loss: 0.2781 - val_RootMeanSquaredError: 0.5374 - val_loss: 0.2888
# Epoch 115/150
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 303us/step - RootMeanSquaredError: 0.5144 - loss: 0.2647 - val_RootMeanSquaredError: 0.5970 - val_loss: 0.3564
# Epoch 116/150
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 307us/step - RootMeanSquaredError: 0.5179 - loss: 0.2682 - val_RootMeanSquaredError: 0.5393 - val_loss: 0.2908
# Epoch 117/150
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 322us/step - RootMeanSquaredError: 0.5307 - loss: 0.2817 - val_RootMeanSquaredError: 0.5620 - val_loss: 0.3158
# Epoch 118/150
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 321us/step - RootMeanSquaredError: 0.5277 - loss: 0.2785 - val_RootMeanSquaredError: 0.5327 - val_loss: 0.2838
# Epoch 119/150
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 316us/step - RootMeanSquaredError: 0.5198 - loss: 0.2703 - val_RootMeanSquaredError: 0.5581 - val_loss: 0.3115
# Epoch 120/150
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 317us/step - RootMeanSquaredError: 0.5185 - loss: 0.2690 - val_RootMeanSquaredError: 0.5518 - val_loss: 0.3045
# Epoch 121/150
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 317us/step - RootMeanSquaredError: 0.5244 - loss: 0.2754 - val_RootMeanSquaredError: 0.5515 - val_loss: 0.3041
# Epoch 122/150
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 307us/step - RootMeanSquaredError: 0.5259 - loss: 0.2767 - val_RootMeanSquaredError: 0.5360 - val_loss: 0.2873
# Epoch 123/150
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 303us/step - RootMeanSquaredError: 0.5147 - loss: 0.2650 - val_RootMeanSquaredError: 0.5351 - val_loss: 0.2863
# Epoch 124/150
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 300us/step - RootMeanSquaredError: 0.5322 - loss: 0.2835 - val_RootMeanSquaredError: 0.5402 - val_loss: 0.2918
# Epoch 125/150
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 392us/step - RootMeanSquaredError: 0.5208 - loss: 0.2715 - val_RootMeanSquaredError: 0.5364 - val_loss: 0.2877
# Epoch 126/150
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 303us/step - RootMeanSquaredError: 0.5218 - loss: 0.2725 - val_RootMeanSquaredError: 0.5265 - val_loss: 0.2772
# Epoch 127/150
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 304us/step - RootMeanSquaredError: 0.5187 - loss: 0.2692 - val_RootMeanSquaredError: 0.5686 - val_loss: 0.3232
# Epoch 128/150
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 299us/step - RootMeanSquaredError: 0.5227 - loss: 0.2733 - val_RootMeanSquaredError: 0.5316 - val_loss: 0.2826
# Epoch 129/150
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 306us/step - RootMeanSquaredError: 0.5181 - loss: 0.2686 - val_RootMeanSquaredError: 0.5477 - val_loss: 0.3000
# Epoch 130/150
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 312us/step - RootMeanSquaredError: 0.5211 - loss: 0.2717 - val_RootMeanSquaredError: 0.5572 - val_loss: 0.3105
# Epoch 131/150
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 310us/step - RootMeanSquaredError: 0.5076 - loss: 0.2579 - val_RootMeanSquaredError: 0.5357 - val_loss: 0.2870
# Epoch 132/150
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 324us/step - RootMeanSquaredError: 0.5321 - loss: 0.2835 - val_RootMeanSquaredError: 0.5367 - val_loss: 0.2880
# Epoch 133/150
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 312us/step - RootMeanSquaredError: 0.5168 - loss: 0.2673 - val_RootMeanSquaredError: 0.5349 - val_loss: 0.2861
# Epoch 134/150
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 305us/step - RootMeanSquaredError: 0.5062 - loss: 0.2566 - val_RootMeanSquaredError: 0.5579 - val_loss: 0.3113
# Epoch 135/150
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 308us/step - RootMeanSquaredError: 0.5180 - loss: 0.2684 - val_RootMeanSquaredError: 0.5314 - val_loss: 0.2824
# Epoch 136/150
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 312us/step - RootMeanSquaredError: 0.5108 - loss: 0.2612 - val_RootMeanSquaredError: 0.5585 - val_loss: 0.3119
# Epoch 137/150
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 310us/step - RootMeanSquaredError: 0.5140 - loss: 0.2645 - val_RootMeanSquaredError: 0.5424 - val_loss: 0.2942
# Epoch 138/150
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 306us/step - RootMeanSquaredError: 0.5048 - loss: 0.2552 - val_RootMeanSquaredError: 0.6031 - val_loss: 0.3638
# Epoch 139/150
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 408us/step - RootMeanSquaredError: 0.5136 - loss: 0.2639 - val_RootMeanSquaredError: 0.5385 - val_loss: 0.2900
# Epoch 140/150
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 303us/step - RootMeanSquaredError: 0.5176 - loss: 0.2683 - val_RootMeanSquaredError: 0.5472 - val_loss: 0.2995
# Epoch 141/150
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 312us/step - RootMeanSquaredError: 0.5084 - loss: 0.2585 - val_RootMeanSquaredError: 0.5258 - val_loss: 0.2765
# Epoch 142/150
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 319us/step - RootMeanSquaredError: 0.5224 - loss: 0.2731 - val_RootMeanSquaredError: 0.5384 - val_loss: 0.2899
# Epoch 143/150
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 316us/step - RootMeanSquaredError: 0.5190 - loss: 0.2694 - val_RootMeanSquaredError: 0.5538 - val_loss: 0.3067
# Epoch 144/150
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 319us/step - RootMeanSquaredError: 0.5189 - loss: 0.2696 - val_RootMeanSquaredError: 0.5459 - val_loss: 0.2980
# Epoch 145/150
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 319us/step - RootMeanSquaredError: 0.5127 - loss: 0.2629 - val_RootMeanSquaredError: 0.5589 - val_loss: 0.3123
# Epoch 146/150
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 312us/step - RootMeanSquaredError: 0.5081 - loss: 0.2582 - val_RootMeanSquaredError: 0.5539 - val_loss: 0.3068
# Epoch 147/150
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 308us/step - RootMeanSquaredError: 0.5057 - loss: 0.2560 - val_RootMeanSquaredError: 0.5381 - val_loss: 0.2895
# Epoch 148/150
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 312us/step - RootMeanSquaredError: 0.5156 - loss: 0.2659 - val_RootMeanSquaredError: 0.5474 - val_loss: 0.2997
# Epoch 149/150
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 319us/step - RootMeanSquaredError: 0.5095 - loss: 0.2597 - val_RootMeanSquaredError: 0.5433 - val_loss: 0.2952
# Epoch 150/150
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 415us/step - RootMeanSquaredError: 0.5008 - loss: 0.2510 - val_RootMeanSquaredError: 0.5429 - val_loss: 0.2947

# %%
# Show the learning curves.
pd.DataFrame(history.history).plot(figsize=(8, 5))
plt.grid(True)
plt.gca().set_ylim(0, 1)
plt.show()

# %%
# Evaluate the model (outputs the MSE).
loss = model.evaluate(X_test, y_test)
# Out:
# 162/162 ━━━━━━━━━━━━━━━━━━━━ 0s 188us/step - RootMeanSquaredError: 0.5293 - loss: 0.2803

# %% [markdown]
# <b>Observation:</b><br/>
# If we multipy the RMSE with 100000, we get the RMSE expressed in USD.

# %%
# Make predictions for the first 3 instances in the test set.
X_new = X_test[:3]
y_pred = model.predict(X_new)
y_pred
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# array([[0.57349837],
#        [1.0710464 ],
#        [4.7055287 ]], dtype=float32)

# %%
# Compare with the corresponding values target values
y_test[:3]
# Out:
# array([0.477  , 0.458  , 5.00001])

# %% [markdown]
# <b>Observation:</b><br/>
# The second prediction is very bad given the RMSE. The other two predictions are okay.
