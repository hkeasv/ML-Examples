# %% [markdown]
# # Training using the Fashion MNIST dataset
# We will train and evaluate an MLP on the Fashion MNIST dataset. It consists of 70.000 grayscale images of 28x28 pixels each, and there are 10 classes.
#
# Hyperparameters:
# 1. Optimizer: Stochastic Gradient Descent
# 2. Activation function: RELU
# 3. Weight initialization: Default (glorot_uniform)

# %% [markdown]
# ## Setup

# %%
# Common imports
import os
import numpy as np
import pandas as pd
import keras

# Select backend. Default is "tensorflow". Alternatives are "jax" and "torch".
os.environ["KERAS_BACKEND"] = "tensorflow"

# To plot pretty figures
# %matplotlib inline
import matplotlib.pyplot as plt

# %% [markdown]
# ## Load the data

# %%
fashion_mnist = keras.datasets.fashion_mnist
(X_train_full, y_train_full), (X_test, y_test) = fashion_mnist.load_data()

# %%
# Split the full training set into a validation set and a (smaller) training set.
# Normalize the data
X_valid, X_train = X_train_full[:5000] / 255.0, X_train_full[5000:] / 255.0
y_valid, y_train = y_train_full[:5000], y_train_full[5000:]
X_test = X_test / 255.0

# %%
X_train.shape
# Out:
# (55000, 28, 28)

# %% [markdown]
# ## Create a model using the Sequential API

# %%
model = keras.models.Sequential()
# Input layer:
model.add(keras.layers.Flatten(input_shape=[28, 28]))

# Hidden layers:
for layer in range(3):
    model.add(keras.layers.Dense(100, activation="relu"))
        
# Output layer.
model.add(keras.layers.Dense(10, activation="softmax"))
# Out:
# /Users/hk/opt/anaconda3/lib/python3.12/site-packages/keras/src/layers/reshaping/flatten.py:37: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)

# %% [markdown]
# ## Compile the model
# You must at least specify the loss function and the optimizer to use. You can also specify a list of additional metrics to use during training and evaluation.

# %%
model.compile(loss="sparse_categorical_crossentropy",
              optimizer="sgd",
              metrics=["accuracy"])

# %% [markdown]
# ## Train the model

# %%
# EarlyStopping (with rollback to the best model).
early_stopping = keras.callbacks.EarlyStopping(patience=10, restore_best_weights=True)

# Train the model with early stopping.
history = model.fit(X_train, y_train, epochs=60,
                    validation_data=(X_valid, y_valid),
                    callbacks=[early_stopping])
# Out:
# Epoch 1/60
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 1s 378us/step - accuracy: 0.6272 - loss: 1.1070 - val_accuracy: 0.7800 - val_loss: 0.5868
# Epoch 2/60
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 1s 338us/step - accuracy: 0.8133 - loss: 0.5223 - val_accuracy: 0.8386 - val_loss: 0.4639
# Epoch 3/60
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 1s 340us/step - accuracy: 0.8376 - loss: 0.4572 - val_accuracy: 0.8032 - val_loss: 0.5269
# Epoch 4/60
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 1s 353us/step - accuracy: 0.8463 - loss: 0.4300 - val_accuracy: 0.8508 - val_loss: 0.4303
# Epoch 5/60
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 1s 378us/step - accuracy: 0.8556 - loss: 0.4002 - val_accuracy: 0.8500 - val_loss: 0.4410
# Epoch 6/60
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 1s 347us/step - accuracy: 0.8581 - loss: 0.3894 - val_accuracy: 0.8684 - val_loss: 0.3791
# Epoch 7/60
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 1s 353us/step - accuracy: 0.8705 - loss: 0.3673 - val_accuracy: 0.8648 - val_loss: 0.3858
# Epoch 8/60
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 1s 352us/step - accuracy: 0.8714 - loss: 0.3577 - val_accuracy: 0.8642 - val_loss: 0.3692
# Epoch 9/60
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 1s 353us/step - accuracy: 0.8713 - loss: 0.3511 - val_accuracy: 0.8694 - val_loss: 0.3548
# Epoch 10/60
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 1s 350us/step - accuracy: 0.8796 - loss: 0.3365 - val_accuracy: 0.8776 - val_loss: 0.3427
# Epoch 11/60
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 1s 356us/step - accuracy: 0.8835 - loss: 0.3200 - val_accuracy: 0.8730 - val_loss: 0.3550
# Epoch 12/60
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 1s 355us/step - accuracy: 0.8858 - loss: 0.3151 - val_accuracy: 0.8750 - val_loss: 0.3393
# Epoch 13/60
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 1s 355us/step - accuracy: 0.8873 - loss: 0.3084 - val_accuracy: 0.8708 - val_loss: 0.3604
# Epoch 14/60
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 1s 362us/step - accuracy: 0.8897 - loss: 0.3038 - val_accuracy: 0.8742 - val_loss: 0.3561
# Epoch 15/60
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 1s 359us/step - accuracy: 0.8928 - loss: 0.2965 - val_accuracy: 0.8802 - val_loss: 0.3251
# Epoch 16/60
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 1s 362us/step - accuracy: 0.8952 - loss: 0.2907 - val_accuracy: 0.8762 - val_loss: 0.3378
# Epoch 17/60
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 1s 355us/step - accuracy: 0.8969 - loss: 0.2844 - val_accuracy: 0.8862 - val_loss: 0.3191
# Epoch 18/60
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 1s 359us/step - accuracy: 0.8998 - loss: 0.2760 - val_accuracy: 0.8796 - val_loss: 0.3396
# Epoch 19/60
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 1s 355us/step - accuracy: 0.8988 - loss: 0.2768 - val_accuracy: 0.8804 - val_loss: 0.3250
# Epoch 20/60
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 1s 361us/step - accuracy: 0.9011 - loss: 0.2731 - val_accuracy: 0.8852 - val_loss: 0.3174
# Epoch 21/60
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 1s 361us/step - accuracy: 0.9030 - loss: 0.2621 - val_accuracy: 0.8750 - val_loss: 0.3318
# Epoch 22/60
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 1s 364us/step - accuracy: 0.9063 - loss: 0.2568 - val_accuracy: 0.8808 - val_loss: 0.3263
# Epoch 23/60
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 1s 387us/step - accuracy: 0.9060 - loss: 0.2554 - val_accuracy: 0.8896 - val_loss: 0.3070
# Epoch 24/60
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 1s 356us/step - accuracy: 0.9094 - loss: 0.2494 - val_accuracy: 0.8810 - val_loss: 0.3267
# Epoch 25/60
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 1s 355us/step - accuracy: 0.9102 - loss: 0.2446 - val_accuracy: 0.8880 - val_loss: 0.3161
# Epoch 26/60
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 1s 357us/step - accuracy: 0.9110 - loss: 0.2404 - val_accuracy: 0.8886 - val_loss: 0.3164
# Epoch 27/60
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 1s 356us/step - accuracy: 0.9118 - loss: 0.2355 - val_accuracy: 0.8858 - val_loss: 0.3130
# Epoch 28/60
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 1s 361us/step - accuracy: 0.9130 - loss: 0.2376 - val_accuracy: 0.8912 - val_loss: 0.3162
# Epoch 29/60
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 1s 361us/step - accuracy: 0.9166 - loss: 0.2293 - val_accuracy: 0.8850 - val_loss: 0.3365
# Epoch 30/60
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 1s 363us/step - accuracy: 0.9152 - loss: 0.2308 - val_accuracy: 0.8886 - val_loss: 0.3194
# Epoch 31/60
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 1s 359us/step - accuracy: 0.9176 - loss: 0.2241 - val_accuracy: 0.8910 - val_loss: 0.3082
# Epoch 32/60
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 1s 362us/step - accuracy: 0.9186 - loss: 0.2170 - val_accuracy: 0.8920 - val_loss: 0.3176
# Epoch 33/60
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 1s 365us/step - accuracy: 0.9211 - loss: 0.2167 - val_accuracy: 0.8846 - val_loss: 0.3251

# %%
# Show the learning curves.
# (The training curves should be shifted half an epoch to the left to be completely comparable with
# the validation curves).

pd.DataFrame(history.history).plot(figsize=(8, 5))
plt.grid(True)
plt.gca().set_ylim(0, 1)
plt.show()

# %% [markdown]
# ## Evaluate the model.

# %%
model.evaluate(X_test, y_test)
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 212us/step - accuracy: 0.8813 - loss: 0.3415
# [0.3365398943424225, 0.8805000185966492]
