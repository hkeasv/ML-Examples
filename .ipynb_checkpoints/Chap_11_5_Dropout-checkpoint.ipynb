# %% [markdown]
# # Training using the Fashion MNIST dataset
# We will train and evaluate an MLP on the Fashion MNIST dataset. It consists of 70.000 grayscale images of 28x28 pixels each, and there are 10 classes.
#
# Hyperparameters:
# 1. Optimizer: Momentum optimization
# 2. Activation function: RELU
# 3. Weight initialization: Default (glorot_uniform)
# 4. Learning rate schedule: Performance scheduling
# 5. Regularization: Dropout

# %% [markdown]
# ## Setup

# %%
# Common imports
import os
import numpy as np
import pandas as pd
import keras

# Select backend. Default is "tensorflow". Alternatives are "jax" and "torch".
os.environ["KERAS_BACKEND"] = "tensorflow"

# To plot pretty figures
# %matplotlib inline
import matplotlib.pyplot as plt

# %% [markdown]
# ## Load the data

# %%
fashion_mnist = keras.datasets.fashion_mnist
(X_train_full, y_train_full), (X_test, y_test) = fashion_mnist.load_data()

# %%
# Split the full training set into a validation set and a (smaller) training set.
# Normalize the data
X_valid, X_train = X_train_full[:5000] / 255.0, X_train_full[5000:] / 255.0
y_valid, y_train = y_train_full[:5000], y_train_full[5000:]
X_test = X_test / 255.0

# %%
X_train.shape
# Out:
# (55000, 28, 28)

# %% [markdown]
# ## Create a model using the Sequential API

# %%
model = keras.models.Sequential()
# Input layer:
model.add(keras.layers.Flatten(input_shape=[28, 28]))

# Hidden layers:
for layer in range(3):
    model.add(keras.layers.Dense(100, activation="relu"))

# Use dropout in the last hidden layer.
model.add(keras.layers.Dropout(rate=0.5))

# Output layer.
model.add(keras.layers.Dense(10, activation="softmax"))
# Out:
# /Users/hk/opt/anaconda3/lib/python3.12/site-packages/keras/src/layers/reshaping/flatten.py:37: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)

# %% [markdown]
# ## Compile the model
# You must at least specify the loss function and the optimizer to use. You can also specify a list of additional metrics to use during training and evaluation.

# %%
# The optimixer is Stochastic Gradient Descent with momentum optimization. The momentum is set to 0.9.
# This value usually works well in practice. We use the default learning rate (0.01).
model.compile(loss="sparse_categorical_crossentropy",
              optimizer=keras.optimizers.SGD(momentum=0.9),
              metrics=["accuracy"])

# %% [markdown]
# ## Train the model

# %%
# EarlyStopping (with rollback to the best model).
early_stopping = keras.callbacks.EarlyStopping(patience=10, restore_best_weights=True)

# Performance scheduling
# (multiply the learning rate by a factor when the error stops dropping for a number of epochs, called patience)
lr_scheduler = keras.callbacks.ReduceLROnPlateau(factor=0.5, patience=4)

# Train the model with early stopping or performance scheduling or both. Training is much faster when
# early stopping is used, but a slightly better accuracy is achieved with performance scheduling alone.
history = model.fit(X_train, y_train, epochs=100,
                    validation_data=(X_valid, y_valid),
                    callbacks=[lr_scheduler, early_stopping])
# Out:
# Epoch 1/100
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 1s 419us/step - accuracy: 0.6901 - loss: 0.8583 - val_accuracy: 0.8390 - val_loss: 0.4357 - learning_rate: 0.0100
# Epoch 2/100
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 1s 388us/step - accuracy: 0.8395 - loss: 0.4582 - val_accuracy: 0.8620 - val_loss: 0.3779 - learning_rate: 0.0100
# Epoch 3/100
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 1s 384us/step - accuracy: 0.8559 - loss: 0.4125 - val_accuracy: 0.8662 - val_loss: 0.3774 - learning_rate: 0.0100
# Epoch 4/100
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 1s 385us/step - accuracy: 0.8638 - loss: 0.3804 - val_accuracy: 0.8636 - val_loss: 0.3625 - learning_rate: 0.0100
# Epoch 5/100
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 1s 386us/step - accuracy: 0.8682 - loss: 0.3631 - val_accuracy: 0.8802 - val_loss: 0.3310 - learning_rate: 0.0100
# Epoch 6/100
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 1s 382us/step - accuracy: 0.8739 - loss: 0.3506 - val_accuracy: 0.8770 - val_loss: 0.3291 - learning_rate: 0.0100
# Epoch 7/100
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 1s 387us/step - accuracy: 0.8817 - loss: 0.3335 - val_accuracy: 0.8828 - val_loss: 0.3370 - learning_rate: 0.0100
# Epoch 8/100
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 1s 383us/step - accuracy: 0.8820 - loss: 0.3233 - val_accuracy: 0.8840 - val_loss: 0.3209 - learning_rate: 0.0100
# Epoch 9/100
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 1s 403us/step - accuracy: 0.8888 - loss: 0.3111 - val_accuracy: 0.8856 - val_loss: 0.3275 - learning_rate: 0.0100
# Epoch 10/100
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 1s 397us/step - accuracy: 0.8906 - loss: 0.3003 - val_accuracy: 0.8862 - val_loss: 0.3104 - learning_rate: 0.0100
# Epoch 11/100
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 1s 398us/step - accuracy: 0.8949 - loss: 0.2905 - val_accuracy: 0.8860 - val_loss: 0.3264 - learning_rate: 0.0100
# Epoch 12/100
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 1s 402us/step - accuracy: 0.8928 - loss: 0.2917 - val_accuracy: 0.8848 - val_loss: 0.3283 - learning_rate: 0.0100
# Epoch 13/100
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 1s 426us/step - accuracy: 0.8972 - loss: 0.2780 - val_accuracy: 0.8902 - val_loss: 0.3189 - learning_rate: 0.0100
# Epoch 14/100
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 1s 396us/step - accuracy: 0.8969 - loss: 0.2797 - val_accuracy: 0.8872 - val_loss: 0.3158 - learning_rate: 0.0100
# Epoch 15/100
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 1s 397us/step - accuracy: 0.9084 - loss: 0.2462 - val_accuracy: 0.8942 - val_loss: 0.3045 - learning_rate: 0.0050
# Epoch 16/100
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 1s 399us/step - accuracy: 0.9133 - loss: 0.2332 - val_accuracy: 0.8942 - val_loss: 0.3023 - learning_rate: 0.0050
# Epoch 17/100
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 1s 387us/step - accuracy: 0.9148 - loss: 0.2304 - val_accuracy: 0.8964 - val_loss: 0.3105 - learning_rate: 0.0050
# Epoch 18/100
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 1s 392us/step - accuracy: 0.9147 - loss: 0.2274 - val_accuracy: 0.8908 - val_loss: 0.3211 - learning_rate: 0.0050
# Epoch 19/100
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 1s 391us/step - accuracy: 0.9165 - loss: 0.2223 - val_accuracy: 0.8930 - val_loss: 0.3168 - learning_rate: 0.0050
# Epoch 20/100
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 1s 397us/step - accuracy: 0.9173 - loss: 0.2152 - val_accuracy: 0.8898 - val_loss: 0.3222 - learning_rate: 0.0050
# Epoch 21/100
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 1s 402us/step - accuracy: 0.9217 - loss: 0.2020 - val_accuracy: 0.8996 - val_loss: 0.3100 - learning_rate: 0.0025
# Epoch 22/100
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 1s 404us/step - accuracy: 0.9266 - loss: 0.1947 - val_accuracy: 0.8980 - val_loss: 0.3088 - learning_rate: 0.0025
# Epoch 23/100
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 1s 402us/step - accuracy: 0.9298 - loss: 0.1873 - val_accuracy: 0.8978 - val_loss: 0.3114 - learning_rate: 0.0025
# Epoch 24/100
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 1s 400us/step - accuracy: 0.9302 - loss: 0.1862 - val_accuracy: 0.8970 - val_loss: 0.3182 - learning_rate: 0.0025
# Epoch 25/100
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 1s 396us/step - accuracy: 0.9318 - loss: 0.1832 - val_accuracy: 0.8990 - val_loss: 0.3183 - learning_rate: 0.0012
# Epoch 26/100
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 1s 391us/step - accuracy: 0.9324 - loss: 0.1782 - val_accuracy: 0.8976 - val_loss: 0.3166 - learning_rate: 0.0012

# %%
# Show the learning curves.
# (The training curves should be shifted half an epoch to the left to be completely comparable with
# the validation curves).

pd.DataFrame(history.history).plot(figsize=(8, 5))
plt.grid(True)
plt.gca().set_ylim(0, 1)
plt.show()

# %% [markdown]
# ## Evaluate the model.

# %%
model.evaluate(X_test, y_test)
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 228us/step - accuracy: 0.8854 - loss: 0.3396
# [0.3366248905658722, 0.8862000107765198]
